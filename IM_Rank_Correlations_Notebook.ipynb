# %%
import IM_rank_correlations
# Out:
# 0 18 [ 0  1  2  4  5  9 11 12 14 15 23 24 26 27 32 41 44 45]
# 1 23 [ 3  6  7  8 10 13 18 19 20 21 22 25 28 29 30 31 33 34 35 36 37 42 43]
# 2 5 [16 17 38 39 40]
